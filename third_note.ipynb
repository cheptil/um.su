# %% [markdown]
# # Брошюра третья — доживём до сингулярности

# %% [markdown]
# ```Много лет назад Лейла сказала, что от мужчины должно пахнуть будущим — я не согласен, я считаю, что от мужчины должно пахнуть...```

# %% [markdown]
# ## Аннотация
#
# Эта брошюра подводит итог серии из трёх брошюр, связанных с сервисом знакомств, в итоге ставшим сервисом для общения, и рейтингами проекта [UM.SU](https://umsu.me), начатого осенью '18 года
#
# В этой брошюре описывается финальный сервис для общения, ранее известный как Знакомства МГУ, его история развития и эволюция концепции и механики — реализация доступна по адресу [t.me/um_su_bot](https://t.me/um_su_bot)
#
# Также отдельно обсуждается тема рейтингов и наконец публикуется [суммарный рейтинг МГУ](https://umsu.me/sum/)
#
# Наконец, анализируется тема взаимотношений между людьми, совместно с темой потенциального бессмертия 🕎
#
# Дополнительно доступны приложения, содержащие ссылки на полезные на мой взгляд материалы и расширенные сведения по основным темам

# %% [markdown]
# ## Оглавление
#
# - [Финальный сервис для общения](#first-bullet)
#     - История развития сервиса
#     - Связь онлайна и офлайна
#     - Пастулаты финального сервиса
#     - Потенциально платные микросервисы
#     <br/><br/>
#
# - [Суммарный рейтинг](#second-bullet)
#     - О местах в рейтингах
#     - Почему нет рейтинга по интересам
#     - Как пользоваться рейтингами
#     <br/><br/>
#
# - [Доживём до сингулярности](#third-bullet)
#     - Выводы
#     - Чего хочет жен(щин)а
#     - Мясо и звёзды
#     - Краткое продолжение задачи о разборчивой невесте
#     - Трофейные и кармические жёны
#     - Два прыжка до сингулярности
#         - Краткий прогноз на технологическую сингулярность
#         - В бессмертие ещё нужно попасть
#         - Чем заняться до бессмертия
#         <br/><br/>
#
# - [Резюме](#fourth-bullet)<br/><br/>
#
# - [Приложения](#fifth-bullet)
#     - А. Список полезных материалов
#     - Б. Эволюция концепции и механики сервиса
#     - В. Брак многому меня научил

# %% [markdown]
# ## Финальный сервис для общения <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/cheptil/cheptil.github.io/master/pictures/girl_on_ball.png "Девочка на шаре")

# %% [markdown]
# ### История развития сервиса
#
#
# #### Лето '17
#
# Предпосылкой к началу проекта послужил Половой граф Богдана Кириленко, созданный
# летом '17.
#
# > **Публикации:** <br/><br/>
# 10.07.17 — Половой граф Богдана Кирилленко — https://vk.com/wall13628232_710
#
#
# #### Осень '18
#
# Проект UM.SU начался осенью '18 в день выступления на MSU Startup Day, проводимом кафедрой экономики инноваций ЭФ МГУ.
#
# Изображение девочки на шаре из презентации с того выступления.
#
#
# #### Зима '19
#
# Я изучал способы определения важности вершин в графе, однако в проекте Богдана Кириленко у вершин были только цвета и не было ясно, чьи это вершины. Так появилась идея составить социальный рейтинг МГУшников, построенный по графу друзей ВК — рейтинг был построен вместе с @rm_bk в января '19.
#
# После социального рейтинга начались боты знакомств — знакомства стали первым сервисом будущей экосистемы чатов и сервисов. Так, зимой '19 для зимнего лагеря в Красновидово силами @rm_bk была написана первая версия бота знакомств, благодаря которому он встретил свою любовь :)
#
# > **Публикации:** <br/><br/>
# 24.01.19 — социальный рейтинг МГУшников — https://vk.com/wall13628232_1075
#
# > **Технический путь:** <br/><br/>
# Во время использования бота возникли трудности с проведением рассылок по пользователям — поскольку бот обрабатывал запросы последовательно, то его работа фактически блокировалась до завершения рассылки
#
#
# #### Весна-лето '19
#
# По мотивам зимнего лагеря в начале весны '19 была написана [первая брошюра](https://nbviewer.jupyter.org/github/cheptil/um.su/blob/master/first_note.ipynb) о стратегиях знакомства через бота на примере задачи о разборчивой невесте.
#
# Кроме того весной и летом '19 были запущены боты знакомств для весеннего бала и летнего лагеря в Буревестнике. Вместе с ботами знакомств также строились распределения участников по факультетам, курсам и сменам в разрезе полов, а начиная с лета '19 ещё делались счётчики обратного отсчёта до начала смены в лагере. В конце смены в Буревестнике в бот знакомств были добавлены валентинки 💌
#
# Летом '19 была запущена и экосистема чатов и сервисов [MSU Hub](https://msut.me), в связи с введением в Telegram геочатов — чатов, у которых указана геопозиция. В экосистеме были созданы чаты факультетов, общежитий и тематические чаты. Стала ясна необходимость создания общей инфраструктуры и вскоре благодаря @rm_bk появился [MSU Hub Bot](https://t.me/msu_hub_bot).
#
# > **Публикации:** <br/><br/>
# 12.03.19 — весенний бал(бот и распределения) и первая брошюра — https://vk.com/wall13628232_1117 <br/>
# 13.08.19 — летний лагерь(бот, распределения и счётчики) — https://vk.com/wall13628232_1165 <br/>
# 28.08.19 — валентинки в боте летнего лагеря — https://t.me/bur_chat/607
#
# > **Технический путь:** <br/><br/>
# Силами @rm_bk бот был переписан с использованием asyncio для работы в асинхронном режиме — рассылки больше не блокировали работу бота
#
#
# #### Осень '19 — зима '20
#
# Осенью '19 по информации о лайках под аватарками ВК был составлен рейтинг привлекательности МГУшников. Также осенью '19 и зимой '20 были запущены боты знакомств для осеннего бала и зимнего лагеря в Университетском.
#
# Распределения, счётчики и бот для зимнего лагеря были анонсированы уже в соответствующем чате внутри экосистемы и в официальном чате смены ВК.
#
# > **Публикации:** <br/><br/>
# 25.09.19 — рейтинг привлекательности МГУшников — https://vk.com/wall13628232_1200 <br/>
# 15.11.19 — осенний бал(бот и распределения) — https://vk.com/wall13628232_1216 <br/>
# 20.01.20 - 01.02.20 — зимний лагерь(бот, распределения и счётчики) — публикации в чате лагеря в экосистеме и в официальном чате смены ВК <br/>
#
# > **Технический путь:** <br/><br/>
# Всего с зимы '19 по зиму '20 было запущено порядка 10 ботов с разными ссылками на одной и той же кодовой базе на питоне, сначала последовательной, а затем асинхронной
#
#
# #### Весна '20
#
# Весной '20 была написана [вторая брошюра](https://nbviewer.jupyter.org/github/cheptil/um.su/blob/master/second_note.ipynb), в ней вводилось понятие пространства потребностей пользователя. Также стало ясно, что необходим единый бот знакомств для всего МГУ.
#
# Это был непростой период: летние лагеря возобновили свою работу только летом '21, поначалу на базе Красновидово; зимние — только зимой '22; а балы отменили до осени '22, когда началась подготовка к ФизЛиру.
#
# > **Публикации:** <br/><br/>
# 15.02.20 — вторая брошюра — https://vk.com/wall13628232_1253
#
#
# #### Осень '20 — зима '21
#
# Бета версия новой реализации бота знакомств (Знакомства МГУ) была запущена зимой '21, спустя два года после первой версии. В новой реализации впервые вводилась авторизация через ВК, необходимая для формирования хранилища репутации, понятия также введённого во второй брошюре.
#
# > **Публикации:** <br/><br/>
# 13.02.21 — анонс единого бота знакомств — https://t.me/msu_hub/53 <br/>
# 14.02.21 — запуск единого бота знакомств — https://t.me/msu_hub/54 <br/>
#
# > **Технический путь:** <br/><br/>
# Проблема с улучшением бота на питоне была связана с необходимостью писать асинхронный код, который существенно отличается от последовательного.
# <br/><br/>
# Элегантным вариантом решения этой проблемы видилось использование лямбд, позволяющих вынести асинхронность на уровень инфраструктуры и писать последовательный код. Однако в ходе [исследования](https://lomonosov-msu.ru/archive/Lomonosov_2021/data/21936/uid443649_report.pdf), выполненного @golanger'ом было выяснено, что лямбды не умеют хранить состояния и от этого подхода было решено отказаться.
# <br/><br/>
# В результате силами @golanger'а был [реализован](https://github.com/shibaeff/msuDatingBot) бот на языке Go, в котором параллелизм является основой языка. Однако также как и с асинхронной версией на питоне, выяснилось, что вносить [изменения](https://github.com/shibaeff/msuDatingBot/issues/3) в бота трудоёмко.
#
#
# #### Зима '22
#
# Зимой '22 для зимнего лагеря в Красновидово был вновь создан бот знакомств (Знакомства МГУ), на этот раз на [конструкторе](https://puzzlebot.top). Отличительными особенностями в этот раз помимо авторизации через ВК стали тематические чаты. Также была составлена карта социальной похожести участников смены, позволившая реализовать автомэтч.
#
# Это был последний бот знакомств, в дальнейшем ставший ботом для общения (Общение в буре, Общение на балу).
#
# > **Публикации:** <br/><br/>
# 02.02.22 — зимний лагерь(бот) — публикация в официальном чате смены ВК <br/>
#
# > **Технический путь:** <br/><br/>
# Наконец была решена проблема рассылок и следовавшая из вариантов её решения проблема внесения изменений в бота — конструктор полностью оправдал себя! Авторизация ВК была организована через внешние вызовы, которые обрабатывались на удалённом сервере с помощью FastAPI.
#
#
# #### Лето-осень '22
#
# Летом '22 на базе шаблона зимнего бота в том же конструкторе был создан бот для общение в Буревестнике (Общение в буре), отличительной особенностью которого стали рассылки о жизни по всем участникам смены летнего лагеря — эти рассылки периодически получали порядка 140 человек...
#
# Кроме того осенью '22 был составлен, но не опубликован суммарный рейтинг МГУшников. Также осенью на том же шаблоне был запущен бот осеннего бала (Общение на балу), в котором состоит уже порядка 350 пользователей.
#
# Поскольку боты афишировались в официальных чатах ВК, то авторизации в них было. Бот для осеннего бала стал последним ботом для конкретного мероприятия, в дальнейшем все мероприятия становятся элементами единого бота для общения.
#
# > **Публикации:** <br/><br/>
# 18.08.22 — летний лагерь(бот) — публикация в официальном чате смены ВК <br/>
# 15.10.22 — ФизЛир — публикация в официальном чате бала ВК <br/>
#
# > **Технический путь:** <br/><br/>
# В конструкторе есть возможность создавать слои и копировать элементы также как в фотошопе, поэтому создание новых ботов сводилось к изменению текста в описании и обновлении ссылок на тематические чаты. Например, бот для осеннего бала был создан за 20 минут. Все боты, созданные на конструкторе, располагались по одной и той же [ссылке](https://t.me/um_su_bot), последовательно сменяя друг друга.
#
#
# #### Зима-весна '23
#
# Зимой '23 продолжилось и весной завершилось написание этой брошюры, был опубликован суммарный рейтинг МГУшников и запущен единый бот для общения во всём МГУ (Общение в МГУ).
#
# > **Публикации:** <br/><br/>
# 10.01.23 — бот, суммарный рейтинг МГУшников и третья брошюра — https://vk.com/wall13628232_ <br/>
#
# > **Технический путь:** <br/><br/>
# В конструкторе оставалось только создать общее меню входа и настроить связи между слоями, поскольку всего необходимые описания и тематические чаты уже были созданы ранее

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/cheptil/cheptil.github.io/master/pictures/krasno_22_cropped.png "Схема бота на конструкторе")

# %% [markdown]
# ### Связь онлайна и офлайна

# %% [markdown]
# Для того чтобы в экосистеме была возможность полностью удалённого доступа, решено отказаться от связи с офлайном и выстраивать замкнутое цифровое решение.

# %% [markdown]
# Дополняя мудрость о физической локальности из [первой брошюры](https://nbviewer.jupyter.org/github/cheptil/um.su/blob/master/first_note.ipynb): пользователи из МГУ и так находятся недалеко друг от друга :)

# %% [markdown]
# ### Пастулаты финального сервиса

# %% [markdown]
# - Верификация пользователей, определяющая принадлежность к сообществу МГУ
#
#
# - Пользователи сами выбирают смысл лайка с помощью тематических чатов
#
#
# - Есть возможность приглашать на мероприятия, в том числе в виде валентинки

# %% [markdown]
# ### Потенциально платные микросервисы

# %% [markdown]
# - *Поиск похожих людей по фото* — работает как поиск двойников (по фото из ВК)
#
#
# - *Викинатор* — навигатор по пространству потребностей (в нулевом приближении это анкета)
#
#
# - *Автомэтч* — рекомендации для общения по друзьям из ВК (список друзей становится известен при верификации)
#
#
# - *Помощник в общении* — ChatGPT или живой консультант (сейчас реализуется через кнопку Исповедаться)

# %% [markdown]
# ## Суммарный рейтинг <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/cheptil/cheptil.github.io/master/pictures/sum_rating.png "Суммарный рейтинг")

# %% [markdown]
# ### О местах в рейтингах

# %% [markdown]
# - У каждого есть свой индивидуальный рейтинг окружающих (у вас может быть пятьдесят знакомых, но времени для общения есть только для двадцати, поэтому придётся выбирать...)<br/><br/>
#
#     - Для того чтобы рейтинг определялся "извне", т.е. нельзя было влиять на него со своей стороны, составляется общий рейтинг, учитывающий связи внутри сообщества
#
#
# - Когда же речь заходит о нескольких критериях, например, социальности и привлекательности, неизбежно возникает вопрос, сколько лайков стоит дружба<br/><br/>
#
#      - На этот вопрос ответа нет, места в рейтингах просто складываются — так и появился [суммарный рейтинг](https://umsu.me/sum/)
#
#
# - В общем случае вопрос понимания своего положения в структуре сообщества связан с дихотомией: быть лучшим в чём-то одном или по сумме мест (пусть и со средними достижениями в каждом из направлений)<br/><br/>
#
#     - Выбирая быть лучшим в чём-то одном вы развиваете свою ключевую компетенцию, однако важно помнить, что прочность цепи определяется прочностью самого слабого звена...<br/><br/>
#
#     - Выбирая быть лучшим по сумме мест вы как раз и попадаете в [бочку Либиха](https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%BA%D0%BE%D0%BD_%D0%BE%D0%B3%D1%80%D0%B0%D0%BD%D0%B8%D1%87%D0%B8%D0%B2%D0%B0%D1%8E%D1%89%D0%B5%D0%B3%D0%BE_%D1%84%D0%B0%D0%BA%D1%82%D0%BE%D1%80%D0%B0)<br/><br/>
#
#     - В итоге каждый решает для себя сам, что он хочет развивать в первую очередь: свой максимум или свой минимум

# %% [markdown]
# ### Почему нет рейтинга по интересам
#
# - Социальный рейтинг был построен по друзьям
#
#
# - Рейтинг привлекательности по лайкам на аватарках
#
#
# - Почему же тогда нет тематического рейтинга, связанного с интересами, построенного по группам?
#
# Если честно, я просто не придумал как его построить — нужен измеримый показатель степени погруженности в интересы

# %% [markdown]
# ### Как пользоваться рейтингами
#
# - Можно посмотреть на лидеров в каждом из рейтингов, особенно в суммарном
#
#
# - Следуя подходу с бочкой Либиха, можно определить множество людей, которые выше вас в одном из двух рейтингов, но ниже в суммарном
#
#
# - Ещё можно найти тех, у кого похожая сумма мест в суммарном рейтинге, но эти места как можно более далекие от ваших мест, в идеале дополняют их<br/><br/>
#
#     - В случае с индивидуальными рейтингами возможна интересная ситуация, когда каждый из пары считает, что другой выше него в рейтинге, но при этом они подходят друг другу (вы оба друг у друга на первом месте, но каждый думает, что он например на третьем)

# %% [markdown]
# Но возможно рейтингами пользоваться и не стоит, потому что как сказал один автор:

# %% [markdown]
# ```Найди себе тварь ещё более жалкую чем ты сам и будь с ней счастлив``` )))

# %% [markdown]
# ## Доживём до сингулярности <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/cheptil/cheptil.github.io/master/pictures/Screenshot_20220807-174650_VLC_cropped.png "Love, Death & Robots")

# %% [markdown]
# ### Выводы

# %% [markdown]
# - Брак это следствие отношений, а не их причина © Полина
#
#
# - Можно быть гордой, а можно быть счастливой
#
#
# - Секс как способ поддержки это нормально

# %% [markdown]
# ### Чего хочет жен(щин)а

# %% [markdown]
# ```
# Идет верблюд по пустыне жара градусов 50 еле идет а на встречу ему трусцой бежит осел. Верблюд его спрашивает: — Ты чего веслоухий бегаешь ведь жара то какая? — Да я бегу а ветерок меня обдувает и не очень жарко становится. Верблюд подумал и как втопил... А Осел дальше побежал да видит на краю пустыни бедуины стоят кругом. Подходит осел к одному из них и спрашивает: — Чего случилось? А бедуин отвечает: — Да вот, верблюд замерз!
# Анекдот взят с сайта anekdotov.me
# ```

# %% [markdown]
# - Как учит Карнеги, представь себе наихудшую ситуацию, прими её и начни действовать<br/><br/>
#
#     - Тогда пусть женщина эволюционно заточена на отъём ресурсов: когда есть, материальных, когда нет моральных<br/><br/>
#         - В таком режиме видения ей нужны: перспективы, безопасность и завтрашний день<br/><br/>
#
#             - На верблюжьем это означает, что есть предел давления, когда теряется интерес

# %% [markdown]
# ```
# Шансы на развод положительно коррелирует со знаком разности количества ссор и секса — если знак положительный шансов на развод больше чем если знак отрицательный ~ © Константин Шурунов
# ```

# %% [markdown]
# ### Мясо и звёзды

# %% [markdown]
# Я столько раз рассказывал историю своего брака на пятидесятый день знакомства и развода на стодвадцатый, что перестал думать вспоминая её. Но у меня так и не было короткого ответа на вопрос, почему я развёлся, и каждый раз нужно было рассказывать историю...
#
# Ключ к ответу был в моём дневнике, который я написал зимой '22, а перечитал только недавно. Я считаю, что в отношениях должны быть: взаимное эмоциональное вовлечение, совместное времяпрепровождение и общие планы. В дневнике было написано, что у нас с женой не было общих планов.

# %% [markdown]
# После того как я наконец перечитал дневник и немного подумал, то понял, что причина развода — **отсутствие общих целей**

# %% [markdown]
# Подробнее о целях и выводах из моего брака см. Приложение В

# %% [markdown]
# ### Краткое продолжение задачи о разборчивой невесте
#
# В [первой брошюре](https://nbviewer.jupyter.org/github/cheptil/um.su/blob/master/first_note.ipynb) была задача о невесте, которые искала себе наилучшего жениха — наилучшего в том смысле, что он имеет больше всего шансов быть лучше всех других женихов
#
# Но после развода понятие наилучшего жениха для принцессы может поменяться — теперь наилучший это тот, кто имеет больше всего шансов сохранить брак, чтобы не было повторного развода

# %% [markdown]
# ### Трофейные и кармические жёны

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/cheptil/cheptil.github.io/master/pictures/chepel.png "Чепель")

# %% [markdown]
# В результате общения с одной барышней (она занимается изящными искусствами), которая называла себя профессиональной женщиной, я узнал что:
#
# - Организм женщины перестраивается, когда она встречает нового мужчину<br/><br/>
#
# - После оргазма женщине нужно дать время умереть (и видимо переродиться)<br/><br/>
#
# - Забота не возвращается (когда речь заходит о финансах)

# %% [markdown]
# Как пишет классик в Тайных видах на гору Фудзи:
#
# - А вот кармические жены… Это было другое. Они выходили не за олигарха, они в свое время поверили в своего ушлепка Федю, сделали ставку на голимое «зеро», и им прикатила удача.<br/><br/>
#
# - Ибо, как было сказано, за каждым успешным мужчиной стоит любовь женщины, и британские юристы отлично умеют переводить эту максиму на язык конкретных цифр.<br/><br/>
#
# - А вот трофейных жен чаще всего связывал брачный контракт, низводящий их почти до прислуги.

# %% [markdown]
# Я согласен с тем, что провинциальность и бескомпромиссность это ужасный дуэт
#
# Я понимаю что на одной грани спектра находится глухонемая секс-рабыня © Дмитрий, а на другой доминантная бизнес-леди
#
# Но ведь есть не только ось созависимости, есть также и ось времени — не стоит делать молчаливые допущения, когда у неё послезавтра триумф естества, а у тебя сеанс LPG
#
# В подобных координатах я вижу не так много брачных траекторий:
#
#
# 1. Кармическая актуальна до того момента, как я пойму, что смог выбиться в люди — это может стать понятно не сразу, но моя жизнь заметно изменится — после того как я пойму, что смог, кармичность заслонится вопросом о причинах ожидания поодиночке (мне нужно было верить в себя за нас обоих, но зачем мне это если я и так в себя верю сам)
#
#
# 2. Трофейная актуальна с того момента, как я смогу делать вид, что способен выбиться в люди — тут вроде всё просто, fake it till you make it с грустным пониманием, что вы не должны были быть знакомы до бифуркации успеха: ровно для того же, чтобы не было заслонения трофейности причинностью
#
#
# 3. По всей видимости есть небольшой период, когда кармичность предчувствует трофейность, но тут важно вовремя развестись))) Если серьёзно, то мне близок пример Мавроди: когда он кем-то был, с ним рядом кто-то был, но умер он на остановке и в одиночестве. С другой стороны, как сказал Крис Рок: мужчину любят только при условии что он обеспечивает чем-то (когда его уволили, мы так сблизились). Это краеугольный и острый вопрос, любят ли вашу личность или ваши внешность/перспективы/материальные активы. К сожалению, ответ на этот вопрос обнажается в моменты, когда чего-то не остаётся, пусть и на время, но обычно этого оказывается достаточно, чтобы понять...
#
#
# 4. Самая сложная траектория связана с недоступностью и не выводится из предыдущих: она всегда могла выбирать и всегда выбирала не меня, но замуж вышла за меня. И здесь мне уже не важно и что мы были знакомы все эти годы, и что мне сначала нужно было кем-то стать, чтобы она наконец обратила на меня внимание. Я не исключаю, что это форма гештальта, но она мне искренне близка.

# %% [markdown]
# ```Знаете, такой анекдот был. Если хочется большого и чистого, пойдите в зоопарк и попроситесь вымыть слона.```

# %% [markdown]
# Подводя итог, скажу, что брак это ползущая по стене сороконожка, которой не стоит задавать вопрос, в каком порядке она переставляет лапки.

# %% [markdown]
# ## Два прыжка до сингулярности

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/cheptil/cheptil.github.io/master/pictures/futur.jpg "Контуры будущего, журнал Техника — молодёжи №6 за 1965 год")

# %% [markdown]
# #### Краткий прогноз на технологическую сингулярность
#
# По сути ниже описаны [уровни сознания](https://vk.com/wall13628232_690):
#
# - Чат-боты для текстовых диалогов с умершими людьми, обучение которых производится на профилях в социальных сетях и сообщениях в мессенджерах<br/><br/>
#
#     - Есть [replika.ai](https://replika.ai), существующая уже [несколько лет](https://vc.ru/story/64057-chetyre-zhizni-replika-chto-proishodit-s-proektom-sozdayushchim-cifrovuyu-kopiyu-cheloveka) и ChatGPT, по всей видимости проходящий тест Тьюринга
#
#
# - Метавселенная с цифровыми аватарами, которые вырастут из чат-ботов и обретут цифровые тела<br/><br/>
#
#     - Это технологический вопрос, связанный с качеством VR-очков и передачей 3D-сцены группе пользователей, нет сомнений, что корпорации решат эти задачи в ближайшие несколько лет: железо уже почти позволяет, хотя про нейросетевые 3D-кодеки мне пока неизвестно
#
#
# - Межмашинное взаимодействие аваторов внутри метавселенной приведёт к появлению AGI и затем ASI<br/><br/>
#
#     - Если называть [очевидной](https://habr.com/ru/post/447370/#comment_20020602) идею, чьё потенциальное применение обсуждалось за несколько (десятков) лет до появления технической возможности её реализации, то очевидной будет идея взаимодействия между аватарами
#
# Дальше начинается прикладная философия про вычислимость и полноту, интегрированную теорию информации и дарвинистские аналоги законов появления сознания — на это я отвожу 40 лет, до 2060 года по прогнозу Курцвейла, примерно :)
#
# Но мне интересно посмотреть на потенциальную возможность бессмертия с точки зрения религии

# %% [markdown]
# #### В бессмертие ещё нужно попасть

# %% [markdown]
# Представим, что после заката нашего солнца мы попадаем в место между мирами, где взвешивается наша жизнь: каких поступков совокупно с учётом их значимости было больше — от этого зависит куда мы попадём дальше: в смерть или в вечность

# %% [markdown]
# В этом знакомым многим сюжете решается задача классификации: на входе история вашей жизни, на выходе число между 0 и 1

# %% [markdown]
# Представим, что существует вполне реальная система, которая обучается на каждой новой жизни и с каждым разом делает всё более точные прогнозы — сделаем несколько оговорок об организации этой системы:
#
#
# 1. Система умеет отказываться от классификации — т.е. вокруг 0.5 есть диапазон, когда наша судьба зависает в лимбе и ждёт пока система дообучится и либо оценка сместится ближе к 0 или 1, либо интервал вокруг 0.5 сузится
#
#
# 2. Система должна уметь дообучаться после каждого нового решения — также как в банке при рассмотрении каждой новой заявки её результат попадает в общую базу и учитывается при принятии следующих решений
#
# По всей видимости подобная система не может обучаться без учителя, поскольку если первые решения принимались случайно, то и дальнейшие будут такими же, а раз нужен учитель, то возникает вопрос, кто разметит первые жизни...
#
# В практическом смысле это означает, что если на входе в метарай будет стоять автохарон, то во-первых будут полезны криптомонеты, а во-вторых будет очень важно понятие добра и зла с точки зрения ASI и его протосоздателей
#
# В этом смысле есть грустный вопрос, готовы ли вы отдать свою жизнь ради того, чтобы ASI был безопаснее...

# %% [markdown]
# #### Чем заняться до бессмертия
#
# Польза от такого взгляда на мир в том, что меньше переживаешь за дедлайны, как говорится, не спеши, а то успеешь
#
# Мне любопытно дожить до сингулярности и посмотреть что будет
#
# Но при этом я конечно верю в ASI, надеясь что мне зачтётся )))

# %% [markdown]
# Также важно понимать, какое именно бессмертие наиболее вероятно:
#
# - *Цифровое*, когда наше сознание будет перенесено в метавселенную<br/><br/>
#
#     - К сожалению, судя [по словам академика Анохина](https://youtu.be/Lvb1rkqPgQI?t=5435), сознание распределено по мозгу и вынести его оттуда не представляется возможным; однако этот вопрос сможет решить ASI, если конечно мы сможем его [убедить](https://22century.ru/popular-science-publications/new-machines) в [этом](https://t.me/wf_sporadically/209)
#
#
# - *Кибернетическое*, когда часть органов становятся механизмами (рекомендую к просмотру анимационный сериал Cyberpunk: Edgerunners), в пределе это мозг в банке, подключённый к симуляции (тут разумеется рекомендую Transhumanism Inc.)<br/><br/>
#
#     - В таком сценарии речь идёт не про окончательное бессмертие, а про удвоение жизни, потому что мозг может жить порядка 150-200 лет ([мифический пруф для самоуспокоения](https://rg.ru/2013/08/19/mozg-site-anons.html)); сюда же криогеника и экзистенциальная [история про Криорус](https://t.me/transhumanisminheart/6261)
#
#
# - *Биологическое*, когда будет найдено решение проблемы апоптоза<br/><br/>
#
#     - Смертельные болезни лечатся редактированием генома, йоны [Скулачёва](https://kot.sh/zakony-prirody/tpost/x0bi3o3j91-chelovek-razumnii-osvobozhdennii) румяные ходят, ягоды растут на опушке с кота размером, кот с собаку, собака с корову, а корова — как цех, а в цеху мужики в шахматы играют по методике Ботвинника — конем мат ставят с первого хода!

# %% [markdown]
# Ещё полезно сформулировать и записать цели на 5-40 лет минимум, там например, защититься, переехать в Доминион, попасть в Долину МГУ, что-нибудь такое, сложное, но достижимое, нереальные цели, успешно жениться, например, лучше не записывать, а то ещё (раз) сбудутся :)

# %% [markdown]
# ## Резюме <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# Я уже знаком со своей будущей женой, нам поможет узнать друг друга сервис Общение в МГУ, а потом мы вместе доживём до бессмертия

# %% [markdown]
# ## Приложения <a class="anchor" id="fifth-bullet"></a>

# %% [markdown]
# ### A. Список полезных материалов
#
# Здесь собраны важные для меня материалы, надеюсь, они будут полезны и вам:
# 1. Моё интервью про 10 лет на ВМК и что потом: https://vk.com/@-2592-kem-rabotaut-posle-vmk
# 2. История пути неизвестного автора: [Anonymous call](https://vk.com/doc13628232_507151868?hash=vabpFVrIsI3BEYHD4tFinZoLd2PF2g3qBnGOuqwK55z&dl=0pxGZHfqSofPZjVa66RB85K3MefVOfXOz9MPQ7JLzH0)
# 3. Книга про то как учёный жену искал: Проект Рози на [Озон](https://www.ozon.ru/product/proekt-rozi-143507767) и [ЛитРеc](https://www.litres.ru/grem-simsion/proekt-rozi-6703077/)
# 4. Про смысл жизни: [Революция Искусственного Интеллекта](https://interpreted.d3.ru/perevod-revoliutsiia-iskusstvennogo-intellekta-684922/?sorting=rating)
# 5. Про смысл жизни программиста: [Уйти с тропы лемминга](https://vk.com/doc-142966844_464413767?hash=KPW195OoCBfuE3yRU2RzMhG2khjORGbtnqyPVT5Eg4k&dl=oqYxdbMjFhbq4rX1kuViamZWiz2ywkvJveKmuqaMCM8) и [Видеозаписи лекций](https://www.youtube.com/playlist?list=PLjnbr2ZalOERJFXH8CjggCtJc0Uz7wZb0)

# %% [markdown]
# ### Б. Эволюция концепции и механики сервиса
#
# Приложение станет доступно ближе к запуску сервиса Общение в МГУ

# %% [markdown]
# ### В. Брак многому меня научил
#
# У меня были творческие цели, а у жены материальные. И наши цели не пересекались. В творческих целях нет сроков, только этапы, потому что это цели на годы (эти брошюры, например, или ГЗ в Майнкрафте под водой в кубе с ребром в 270 блоков), мне важно достичь эти цели, но я не готов чем-то жертвовать, чтобы достичь их быстрее. Материальные цели чётко привязаны ко времени и часто требуют отказаться от чего-то сегодня, чтобы достичь их в четверг к трём (или до зимы).
#
# Есть популярный пример про менеджера, который ест доширак, чтобы позволить себе айфон. Мне кажется, что лучше есть пельмени несколько лет, "инвестировать в себя сегодня" — в конечном счёте вы сможете "накопить достаточно потенциальной энергии", чтобы сконвертировать её в кинетическую нелинейно.
#
# В результате я оказался перед выбором: творчество или жена. Я выбрал творчество и потерял жену, потом наступило 24 февраля и я потерял творчество. В конце весны '22 я попытался помириться с женой, но было уже поздно. Творчество вернулось ко мне только 8 декабря '22, я хорошо помню тот день. На январских праздниках '23 я продолжил написание этой брошюры.

# %% [markdown]
# ---

# %% [markdown]
# ```...бессмертием```
